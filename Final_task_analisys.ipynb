# %%
import pandas as pd  #импорт библиотек
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown --id 1aaNNTdzKejRicd-GFIRWbSIH1nnKf4v1
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1aaNNTdzKejRicd-GFIRWbSIH1nnKf4v1
# To: /content/df_clear.csv
# 100% 646k/646k [00:00<00:00, 170MB/s]

# %%
df = pd.read_csv('df_clear.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  index  product_id                                        title  \
# 0           0      0    17880420               компьютер hp prodesk 400 g6 mt
# 1           1      1    19347937      офисный компьютер robotcomp казначей v1
# 2           2      2    19348951       игровой компьютер robotcomp м16 2.0 v1
# 3           3      3    19355097          игровой компьютер robotcomp m-16 v1
# 4           4      4    19358744  игровой компьютер robotcomp анаконда 2.0 v1
#
#     price  sales  feedbacks     seller  seller_rating  \
# 0   35720      0          0        NaN            NaN
# 1   39237     10          1  Robotcomp            4.7
# 2   76188    200         94  Robotcomp            4.7
# 3   55625     40         12  Robotcomp            4.7
# 4  128284      5          4  Robotcomp            4.7
#
#                   graphics operating_system country       cpu_type  \
# 0             не заполнено      отсутствует     NaN   не заполнено
# ...
